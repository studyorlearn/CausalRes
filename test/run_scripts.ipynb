# %%
import sys
import os
sys.path.append('..')

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
# from utils import test_utils, data_utils
from utils.test_utils import Tester
from models.models import MLP, CNN, CNNResNet, CausalCNNResNet
from utils.data_utils import get_dataloader, get_data_tag

rcParams['svg.fonttype'] = 'none'
rcParams['font.family'] = 'SimHei'
rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 1 Low Probability Test

# %%
data, tag = get_data_tag(faultP=[0, 1], desample=512)
train_loader, test_loader = get_dataloader(data, tag)
# Out:
# Train set size: 16048
# Test set size: 4012

# %% [markdown]
# ## 1.1 Causal-Res

# %%
# Causal_Res high probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        model = CausalCNNResNet(6, 16, 10, 32, 1024, 3, 22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'low_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del model, tester
        print("----------------------------------------------------------------------\n")
       
run_scripts(20)
# Out:
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001027, Train accuracy: 0.9982
# [INFO] EPOCH: 20/20
# Train loss: 0.000368, Train accuracy: 0.9988
# [INFO] The running time is: 203.20117735862732s
#
# [INFO] Test loss: 0.000143, Test accuracy: 100.0000
# [INFO] The running time is: 0.5412144660949707s
#
# Save metrics to model_CausalCNNResNet_1_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_1_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001010, Train accuracy: 0.9982
# [INFO] EPOCH: 20/20
# Train loss: 0.000344, Train accuracy: 0.9987
# [INFO] The running time is: 206.71295952796936s
#
# [INFO] Test loss: 0.000131, Test accuracy: 100.0000
# [INFO] The running time is: 0.5370457172393799s
#
# Save metrics to model_CausalCNNResNet_2_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_2_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001480, Train accuracy: 0.9953
# [INFO] EPOCH: 20/20
# Train loss: 0.000461, Train accuracy: 0.9981
# [INFO] The running time is: 224.13207507133484s
#
# [INFO] Test loss: 0.000174, Test accuracy: 100.0000
# [INFO] The running time is: 0.48783278465270996s
#
# Save metrics to model_CausalCNNResNet_3_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_3_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001073, Train accuracy: 0.9976
# [INFO] EPOCH: 20/20
# Train loss: 0.000376, Train accuracy: 0.9988
# [INFO] The running time is: 191.86012291908264s
#
# [INFO] Test loss: 0.000180, Test accuracy: 99.9500
# [INFO] The running time is: 0.5305321216583252s
#
# Save metrics to model_CausalCNNResNet_4_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_4_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001077, Train accuracy: 0.9979
# [INFO] EPOCH: 20/20
# Train loss: 0.000358, Train accuracy: 0.9988
# [INFO] The running time is: 220.09396052360535s
#
# [INFO] Test loss: 0.000137, Test accuracy: 99.9750
# [INFO] The running time is: 0.5658822059631348s
#
# Save metrics to model_CausalCNNResNet_5_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_5_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001193, Train accuracy: 0.9971
# [INFO] EPOCH: 20/20
# Train loss: 0.000376, Train accuracy: 0.9988
# [INFO] The running time is: 209.99692749977112s
#
# [INFO] Test loss: 0.000154, Test accuracy: 100.0000
# [INFO] The running time is: 0.5585160255432129s
#
# Save metrics to model_CausalCNNResNet_6_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_6_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001371, Train accuracy: 0.9963
# [INFO] EPOCH: 20/20
# Train loss: 0.000447, Train accuracy: 0.9986
# [INFO] The running time is: 211.4124400615692s
#
# [INFO] Test loss: 0.000175, Test accuracy: 100.0000
# [INFO] The running time is: 0.5401690006256104s
#
# Save metrics to model_CausalCNNResNet_7_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_7_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001125, Train accuracy: 0.9976
# [INFO] EPOCH: 20/20
# Train loss: 0.000377, Train accuracy: 0.9990
# [INFO] The running time is: 211.5650339126587s
#
# [INFO] Test loss: 0.000179, Test accuracy: 99.9750
# [INFO] The running time is: 0.5865576267242432s
#
# Save metrics to model_CausalCNNResNet_8_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_8_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001316, Train accuracy: 0.9968
# [INFO] EPOCH: 20/20
# Train loss: 0.000393, Train accuracy: 0.9986
# [INFO] The running time is: 230.15903234481812s
#
# [INFO] Test loss: 0.000167, Test accuracy: 100.0000
# [INFO] The running time is: 0.5310475826263428s
#
# Save metrics to model_CausalCNNResNet_9_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_9_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001422, Train accuracy: 0.9967
# [INFO] EPOCH: 20/20
# Train loss: 0.000400, Train accuracy: 0.9988
# [INFO] The running time is: 232.63742852210999s
#
# [INFO] Test loss: 0.000152, Test accuracy: 100.0000
# [INFO] The running time is: 0.5593805313110352s
#
# Save metrics to model_CausalCNNResNet_10_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_10_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001098, Train accuracy: 0.9976
# [INFO] EPOCH: 20/20
# Train loss: 0.000388, Train accuracy: 0.9988
# [INFO] The running time is: 212.0574824810028s
#
# [INFO] Test loss: 0.000155, Test accuracy: 100.0000
# [INFO] The running time is: 0.5329885482788086s
#
# Save metrics to model_CausalCNNResNet_11_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_11_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001206, Train accuracy: 0.9976
# [INFO] EPOCH: 20/20
# Train loss: 0.000395, Train accuracy: 0.9986
# [INFO] The running time is: 230.27884578704834s
#
# [INFO] Test loss: 0.000178, Test accuracy: 99.9500
# [INFO] The running time is: 0.5541436672210693s
#
# Save metrics to model_CausalCNNResNet_12_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_12_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000999, Train accuracy: 0.9980
# [INFO] EPOCH: 20/20
# Train loss: 0.000351, Train accuracy: 0.9987
# [INFO] The running time is: 180.98683190345764s
#
# [INFO] Test loss: 0.000149, Test accuracy: 100.0000
# [INFO] The running time is: 0.5709047317504883s
#
# Save metrics to model_CausalCNNResNet_13_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_13_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001101, Train accuracy: 0.9974
# [INFO] EPOCH: 20/20
# Train loss: 0.000351, Train accuracy: 0.9989
# [INFO] The running time is: 224.4270532131195s
#
# [INFO] Test loss: 0.000148, Test accuracy: 100.0000
# [INFO] The running time is: 0.5097179412841797s
#
# Save metrics to model_CausalCNNResNet_14_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_14_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001104, Train accuracy: 0.9978
# [INFO] EPOCH: 20/20
# Train loss: 0.000341, Train accuracy: 0.9989
# [INFO] The running time is: 196.05311131477356s
#
# [INFO] Test loss: 0.000145, Test accuracy: 100.0000
# [INFO] The running time is: 0.4857521057128906s
#
# Save metrics to model_CausalCNNResNet_15_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_15_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001194, Train accuracy: 0.9971
# [INFO] EPOCH: 20/20
# Train loss: 0.000386, Train accuracy: 0.9988
# [INFO] The running time is: 220.60819506645203s
#
# [INFO] Test loss: 0.000159, Test accuracy: 100.0000
# [INFO] The running time is: 0.5083193778991699s
#
# Save metrics to model_CausalCNNResNet_16_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_16_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001319, Train accuracy: 0.9970
# [INFO] EPOCH: 20/20
# Train loss: 0.000467, Train accuracy: 0.9983
# [INFO] The running time is: 158.35708475112915s
#
# [INFO] Test loss: 0.000161, Test accuracy: 100.0000
# [INFO] The running time is: 0.5307416915893555s
#
# Save metrics to model_CausalCNNResNet_17_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_17_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001243, Train accuracy: 0.9969
# [INFO] EPOCH: 20/20
# Train loss: 0.000386, Train accuracy: 0.9989
# [INFO] The running time is: 206.19816279411316s
#
# [INFO] Test loss: 0.000172, Test accuracy: 99.9500
# [INFO] The running time is: 0.48587679862976074s
#
# Save metrics to model_CausalCNNResNet_18_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_18_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000881, Train accuracy: 0.9986
# [INFO] EPOCH: 20/20
# Train loss: 0.000311, Train accuracy: 0.9989
# [INFO] The running time is: 211.08800101280212s
#
# [INFO] Test loss: 0.000133, Test accuracy: 100.0000
# [INFO] The running time is: 0.5076484680175781s
#
# Save metrics to model_CausalCNNResNet_19_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_19_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.001133, Train accuracy: 0.9974
# [INFO] EPOCH: 20/20
# Train loss: 0.000367, Train accuracy: 0.9988
# [INFO] The running time is: 153.81771230697632s
#
# [INFO] Test loss: 0.000176, Test accuracy: 99.9500
# [INFO] The running time is: 0.510601282119751s
#
# Save metrics to model_CausalCNNResNet_20_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_20_predict_and_label.npy file successfully!
#
# ----------------------------------------------------------------------

# %% [markdown]
# ## 1.2 MLP

# %%
# MLP low probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        model = MLP(input_size=512*6, hidden_sizes=[512, 256, 128, 64, 32], output_size=22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'low_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)

# %% [markdown]
# ## 1.3 CNN

# %%
# CNN low probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        model = CNN(
                    input_channels=512, conv_layers=[(32, 1, 1, 1), (64, 1, 1, 1)], fc_layers=[128], num_classes=22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'low_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)

# %% [markdown]
# ## 1.4 CNN-ResNet

# %%
# CNN-ResNet low probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        cnn = CNN(
                    input_channels=512, conv_layers=[(32, 1, 1, 1), (64, 1, 1, 1)], fc_layers=[128], num_classes=22)
        model = CNNResNet(cnn, 22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'low_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del cnn, model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)

# %% [markdown]
# # 2 High Probability Test

# %%
data, tag = get_data_tag(faultP=[2, 3, 4], desample=512)
train_loader, test_loader = get_dataloader(data, tag)
# Out:
# Train set size: 24072
# Test set size: 6018

# %% [markdown]
# ## 2.1 Causal-Res

# %%
# Causal_Res high probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        model = CausalCNNResNet(6, 16, 10, 32, 1024, 3, 22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'high_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)
# Out:
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000599, Train accuracy: 0.9984
# [INFO] EPOCH: 20/20
# Train loss: 0.000257, Train accuracy: 0.9988
# [INFO] The running time is: 306.98567295074463s
#
# [INFO] Test loss: 0.000130, Test accuracy: 99.9501
# [INFO] The running time is: 0.7272570133209229s
#
# Save metrics to model_CausalCNNResNet_1_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_1_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 1 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000653, Train accuracy: 0.9980
# [INFO] EPOCH: 20/20
# Train loss: 0.000211, Train accuracy: 0.9993
# [INFO] The running time is: 330.9297957420349s
#
# [INFO] Test loss: 0.000068, Test accuracy: 99.9668
# [INFO] The running time is: 0.7660317420959473s
#
# Save metrics to model_CausalCNNResNet_2_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_2_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 2 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000578, Train accuracy: 0.9980
# [INFO] EPOCH: 20/20
# Train loss: 0.000227, Train accuracy: 0.9987
# [INFO] The running time is: 290.19618797302246s
#
# [INFO] Test loss: 0.000102, Test accuracy: 99.9501
# [INFO] The running time is: 0.8257861137390137s
#
# Save metrics to model_CausalCNNResNet_3_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_3_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 3 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000671, Train accuracy: 0.9977
# [INFO] EPOCH: 20/20
# Train loss: 0.000257, Train accuracy: 0.9988
# [INFO] The running time is: 262.4703559875488s
#
# [INFO] Test loss: 0.000100, Test accuracy: 99.9834
# [INFO] The running time is: 0.8282172679901123s
#
# Save metrics to model_CausalCNNResNet_4_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_4_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 4 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000600, Train accuracy: 0.9982
# [INFO] EPOCH: 20/20
# Train loss: 0.000214, Train accuracy: 0.9992
# [INFO] The running time is: 324.6783871650696s
#
# [INFO] Test loss: 0.000098, Test accuracy: 99.9501
# [INFO] The running time is: 0.8224072456359863s
#
# Save metrics to model_CausalCNNResNet_5_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_5_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 5 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000494, Train accuracy: 0.9984
# [INFO] EPOCH: 20/20
# Train loss: 0.000215, Train accuracy: 0.9990
# [INFO] The running time is: 329.54873394966125s
#
# [INFO] Test loss: 0.000087, Test accuracy: 99.9834
# [INFO] The running time is: 0.8198745250701904s
#
# Save metrics to model_CausalCNNResNet_6_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_6_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 6 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000634, Train accuracy: 0.9982
# [INFO] EPOCH: 20/20
# Train loss: 0.000232, Train accuracy: 0.9993
# [INFO] The running time is: 331.22093176841736s
#
# [INFO] Test loss: 0.000089, Test accuracy: 99.9501
# [INFO] The running time is: 0.9426681995391846s
#
# Save metrics to model_CausalCNNResNet_7_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_7_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 7 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000527, Train accuracy: 0.9979
# [INFO] EPOCH: 20/20
# Train loss: 0.000238, Train accuracy: 0.9985
# [INFO] The running time is: 347.8893618583679s
#
# [INFO] Test loss: 0.000097, Test accuracy: 99.9668
# [INFO] The running time is: 0.7779288291931152s
#
# Save metrics to model_CausalCNNResNet_8_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_8_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 8 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000634, Train accuracy: 0.9983
# [INFO] EPOCH: 20/20
# Train loss: 0.000237, Train accuracy: 0.9992
# [INFO] The running time is: 348.46660232543945s
#
# [INFO] Test loss: 0.000099, Test accuracy: 99.9335
# [INFO] The running time is: 0.7771275043487549s
#
# Save metrics to model_CausalCNNResNet_9_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_9_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 9 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000612, Train accuracy: 0.9972
# [INFO] EPOCH: 20/20
# Train loss: 0.000260, Train accuracy: 0.9986
# [INFO] The running time is: 311.3187155723572s
#
# [INFO] Test loss: 0.000121, Test accuracy: 99.9335
# [INFO] The running time is: 0.7822844982147217s
#
# Save metrics to model_CausalCNNResNet_10_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_10_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 10 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000532, Train accuracy: 0.9976
# [INFO] EPOCH: 20/20
# Train loss: 0.000229, Train accuracy: 0.9989
# [INFO] The running time is: 330.30384826660156s
#
# [INFO] Test loss: 0.000092, Test accuracy: 99.9335
# [INFO] The running time is: 0.77848219871521s
#
# Save metrics to model_CausalCNNResNet_11_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_11_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 11 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000705, Train accuracy: 0.9981
# [INFO] EPOCH: 20/20
# Train loss: 0.000253, Train accuracy: 0.9992
# [INFO] The running time is: 325.62474179267883s
#
# [INFO] Test loss: 0.000114, Test accuracy: 99.9335
# [INFO] The running time is: 0.7384960651397705s
#
# Save metrics to model_CausalCNNResNet_12_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_12_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 12 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000623, Train accuracy: 0.9970
# [INFO] EPOCH: 20/20
# Train loss: 0.000288, Train accuracy: 0.9979
# [INFO] The running time is: 289.7215905189514s
#
# [INFO] Test loss: 0.000127, Test accuracy: 99.9335
# [INFO] The running time is: 0.899749755859375s
#
# Save metrics to model_CausalCNNResNet_13_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_13_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 13 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000631, Train accuracy: 0.9981
# [INFO] EPOCH: 20/20
# Train loss: 0.000243, Train accuracy: 0.9990
# [INFO] The running time is: 291.1120262145996s
#
# [INFO] Test loss: 0.000092, Test accuracy: 99.9668
# [INFO] The running time is: 0.8099591732025146s
#
# Save metrics to model_CausalCNNResNet_14_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_14_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 14 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000520, Train accuracy: 0.9987
# [INFO] EPOCH: 20/20
# Train loss: 0.000220, Train accuracy: 0.9990
# [INFO] The running time is: 289.29586029052734s
#
# [INFO] Test loss: 0.000089, Test accuracy: 99.9501
# [INFO] The running time is: 0.8415381908416748s
#
# Save metrics to model_CausalCNNResNet_15_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_15_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 15 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000562, Train accuracy: 0.9980
# [INFO] EPOCH: 20/20
# Train loss: 0.000231, Train accuracy: 0.9990
# [INFO] The running time is: 322.4632546901703s
#
# [INFO] Test loss: 0.000119, Test accuracy: 99.9501
# [INFO] The running time is: 0.8001503944396973s
#
# Save metrics to model_CausalCNNResNet_16_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_16_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 16 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000786, Train accuracy: 0.9970
# [INFO] EPOCH: 20/20
# Train loss: 0.000333, Train accuracy: 0.9983
# [INFO] The running time is: 334.89692878723145s
#
# [INFO] Test loss: 0.000121, Test accuracy: 99.9169
# [INFO] The running time is: 0.9347476959228516s
#
# Save metrics to model_CausalCNNResNet_17_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_17_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 17 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000467, Train accuracy: 0.9983
# [INFO] EPOCH: 20/20
# Train loss: 0.000192, Train accuracy: 0.9992
# [INFO] The running time is: 295.79508328437805s
#
# [INFO] Test loss: 0.000095, Test accuracy: 99.9668
# [INFO] The running time is: 0.8383727073669434s
#
# Save metrics to model_CausalCNNResNet_18_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_18_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 18 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000666, Train accuracy: 0.9974
# [INFO] EPOCH: 20/20
# Train loss: 0.000242, Train accuracy: 0.9993
# [INFO] The running time is: 277.6810460090637s
#
# [INFO] Test loss: 0.000104, Test accuracy: 99.9501
# [INFO] The running time is: 0.9671952724456787s
#
# Save metrics to model_CausalCNNResNet_19_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_19_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 19 completed-----------------------------------
#
# The device is: cuda
# The tester initialization is completed.
#
# The model is: CausalCNNResNet. Waitting...
# [INFO] EPOCH: 10/20
# Train loss: 0.000522, Train accuracy: 0.9978
# [INFO] EPOCH: 20/20
# Train loss: 0.000225, Train accuracy: 0.9986
# [INFO] The running time is: 288.54278898239136s
#
# [INFO] Test loss: 0.000104, Test accuracy: 99.9169
# [INFO] The running time is: 0.8514144420623779s
#
# Save metrics to model_CausalCNNResNet_20_metrics.json file successfully!
#
# Save predict and label to model_CausalCNNResNet_20_predict_and_label.npy file successfully!
#
# -----------------------------------loopc 20 completed-----------------------------------

# %% [markdown]
# ## 2.2 MLP

# %%
# MLP high probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        model = MLP(input_size=512*6, hidden_sizes=[512, 256, 128, 64, 32], output_size=22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'high_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)

# %% [markdown]
# ## 2.3 CNN

# %%
# CNN high probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        model = CNN(
                    input_channels=512, conv_layers=[(32, 1, 1, 1), (64, 1, 1, 1)], fc_layers=[128], num_classes=22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'high_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)

# %% [markdown]
# ## 2.4 CNN-ResNet

# %%
# CNN-ResNet high probability 
def run_scripts(loop_count=1, epoch=20):
    
    for i in range(loop_count):
        cnn = CNN(input_channels=512, conv_layers=[(32, 1, 1, 1), (64, 1, 1, 1)], fc_layers=[128], num_classes=22)
        model = CNNResNet(cnn, 22)
        tester = Tester(model=model, epoch=epoch)
        tester.train_time_cost = tester.train(train_loader=train_loader)
        tester.test_time_cost = tester.test(test_loader=test_loader)
        tester.save_model(i+1, tag = 'high_probabilty')
        tester.calculate_performance_metrice()
        tester.save_metrics_to_json()
        tester.save_predict_and_label()
        del cnn, model, tester
        print(f"-----------------------------------loopc {i+1} completed-----------------------------------\n")
       
run_scripts(20)
